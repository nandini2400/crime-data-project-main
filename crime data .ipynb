# %%
import pandas as pd
df = pd.read_csv('/Users/rajanandinialla/Downloads/Crime_Data_from_2020_to_Present.csv')

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
df.shape
# Out:
# (982638, 28)

# %%
df.head(5)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174591 entries, 0 to 174590
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           174591 non-null  int64
#  1   Date Rptd       174591 non-null  object
#  2   DATE OCC        174591 non-null  object
#  3   TIME OCC        174591 non-null  int64
#  4   AREA            174591 non-null  int64
#  5   AREA NAME       174591 non-null  object
#  6   Rpt Dist No     174591 non-null  int64
#  7   Part 1-2        174591 non-null  int64
#  8   Crm Cd          174591 non-null  int64
#  9   Crm Cd Desc     174591 non-null  object
#  10  Mocodes         151177 non-null  object
#  11  Vict_Age        174591 non-null  int64
#  12  Vict Sex        152288 non-null  object
#  13  Vict Descent    152285 non-null  object
#  14  Premis Cd       174589 non-null  float64
#  15  Premis Desc     174529 non-null  object
# ...

# %%
max_age = df['Vict_Age'].max()

# %%
max_age
# Out:
# 120.0

# %%
min_age = df['Vict_Age'].min()

# %%
min_age
# Out:
# -4.0

# %%
min_age = df['Vict_Age'].min()
max_age = df['Vict_Age'].max()
median_age = df['Vict_Age'].median()


print(f"Minimum age of victims: {min_age}")
print(f"Maximum age of victims: {max_age}")
print(f"Median age of victims: {median_age}")
# Out:
# Minimum age of victims: -4.0
# Maximum age of victims: 120.0
# Median age of victims: 31.0

# %%
print(df['DATE OCC'].head())
# Out:
# 0     3/1/20 12:00 AM
# 1     2/8/20 12:00 AM
# 2    11/4/20 12:00 AM
# 3    3/10/20 12:00 AM
# 4    8/17/20 12:00 AM
# Name: DATE OCC, dtype: object

# %%
print(df['DATE OCC'].dtype)
# Out:
# object

# %%
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])

# %%
print(df['DATE OCC'].dtype)
# Out:
# datetime64[ns]

# %%
df['DayOfWeek'] = df['DATE OCC'].dt.day_name()

# %%
print(df[['DATE OCC', 'DayOfWeek']].head())
# Out:
#     DATE OCC  DayOfWeek
# 0 2020-03-01     Sunday
# 1 2020-02-08   Saturday
# 2 2020-11-04  Wednesday
# 3 2020-03-10    Tuesday
# 4 2020-08-17     Monday

# %%
df.head()
# Out:
#        DR_NO          Date Rptd   DATE OCC  TIME OCC  AREA  AREA NAME  \
# 0  190326475    3/1/20 12:00 AM 2020-03-01      2130     7   Wilshire
# 1  200106753    2/9/20 12:00 AM 2020-02-08      1800     1    Central
# 2  200320258  11/11/20 12:00 AM 2020-11-04      1700     3  Southwest
# 3  200907217   5/10/23 12:00 AM 2020-03-10      2037     9   Van Nuys
# 4  220614831   8/18/22 12:00 AM 2020-08-17      1200     6  Hollywood
#
#    Rpt Dist No  Part 1-2  Crm Cd                               Crm Cd Desc  \
# 0          784         1     510                          VEHICLE - STOLEN
# 1          182         1     330                     BURGLARY FROM VEHICLE
# 2          356         1     480                             BIKE - STOLEN
# 3          964         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4          666         2     354                         THEFT OF IDENTITY
#
#    ... Crm Cd 1  Crm Cd 2 Crm Cd 3 Crm Cd 4  \
# 0  ...    510.0     998.0      NaN      NaN
# ...

# %%
crime_counts = df['DayOfWeek'].value_counts()

# %%
crime_counts
# Out:
# Friday       26160
# Wednesday    25378
# Saturday     25315
# Thursday     24726
# Monday       24712
# Tuesday      24158
# Sunday       24142
# Name: DayOfWeek, dtype: int64

# %%
most_crimes_day = crime_counts.idxmax()

# %%
most_crimes_day
# Out:
# 'Friday'

# %%
most_crimes_count = crime_counts.max()

# %%
most_crimes_count
# Out:
# 26160

# %%
theft_df = df[df['Crm Cd Desc'] == 'THEFT OF IDENTITY']
theft_df
# Out:
#             DR_NO          Date Rptd   DATE OCC  TIME OCC  AREA  AREA NAME  \
# 4       220614831   8/18/22 12:00 AM 2020-08-17      1200     6  Hollywood
# 5       231808869    4/4/23 12:00 AM 2020-12-01      2300    18  Southeast
# 6       230110144    4/4/23 12:00 AM 2020-07-03       900     1    Central
# 7       220314085   7/22/22 12:00 AM 2020-05-12      1110     3  Southwest
# 8       231309864   4/28/23 12:00 AM 2020-12-09      1400    13     Newton
# ...           ...                ...        ...       ...   ...        ...
# 174357  200907297   3/11/20 12:00 AM 2020-03-11       700     9   Van Nuys
# 174367  201414883   7/31/20 12:00 AM 2020-06-17      1405    14    Pacific
# 174393  201614433   9/30/20 12:00 AM 2020-08-21       205    16   Foothill
# 174543  200915788  10/11/20 12:00 AM 2020-10-10      1820     9   Van Nuys
# 174572  201907191    3/5/20 12:00 AM 2020-02-15         1    19    Mission
#
# ...

# %%
theft_df.to_csv('/Users/rajanandinialla/Desktop/central_area_thefts.csv', index=False)
